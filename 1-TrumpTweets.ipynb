# %%
import pandas as pd
from collections import Counter
import matplotlib

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords') #Stopwords allow filting out words like 'the','a'
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Read in the csv into a dataframe
df = pd.read_csv(r'C:\Users\Admin\Google Drive\3-Data_Science\Python\TrumpTweetsProject\trumptweets.csv')
df.head()
# Out:
#            id                                               link  \
# 0  1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1  1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2  1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3  1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4  1773561338  https://twitter.com/realDonaldTrump/status/177...
#
#                                              content                 date  \
# 0  Be sure to tune in and watch Donald Trump on L...  2009-05-04 20:54:25
# 1  Donald Trump will be appearing on The View tom...  2009-05-05 03:00:10
# 2  Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 15:38:08
# 3  New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 22:40:15
# 4  "My persona will never be that of a wallflower...  2009-05-12 16:07:28
#
#    retweets  favorites mentions hashtags  geo
# 0       500        868      NaN      NaN  NaN
# 1        33        273      NaN      NaN  NaN
# 2        12         18      NaN      NaN  NaN
# 3        11         24      NaN      NaN  NaN
# 4      1399       1965      NaN      NaN  NaN

# %%
#Count distinct words. There are a lot of stop words here
Counter(" ".join(df["content"]).split()).most_common(20)
# Out:
# [('@', 38059),
#  ('the', 26851),
#  ('to', 17900),
#  ('and', 13660),
#  ('a', 12588),
#  ('of', 12076),
#  ('is', 11457),
#  ('in', 10235),
#  ('"', 9691),
#  ('for', 8901),
#  ('I', 8414),
#  ('realDonaldTrump', 7831),
#  ('#', 7188),
#  ('on', 7141),
#  ('you', 6106),
#  ('be', 6064),
#  ('will', 5300),
#  ('are', 4989),
#  ('that', 4948),
#  ('with', 4430)]

# %%
#Count distinct word into a series
word_df = pd.Series(' '.join(df['content']).lower().split()).value_counts()[:80]

#Convert the series into a dataframe to enable filtering
word_df = word_df.to_frame(name = 'count').reset_index()

#Clean the headers
word_df.rename(columns={'index':'word'}, inplace=True)

word_df.head(20)
# Out:
#                word  count
# 0                 @  38059
# 1               the  31400
# 2                to  18264
# 3               and  14014
# 4                 a  13689
# 5                of  12271
# 6                is  11767
# 7                in  10805
# 8                 "   9691
# 9               for   9234
# 10                i   8542
# 11  realdonaldtrump   7936
# 12               on   7388
# 13              you   7320
# 14                #   7188
# 15               be   6362
# 16             will   5998
# 17            great   5321
# 18             that   5185
# 19              are   5133

# %%
#Manual filtering, depricated
#word_df = word_df[~word_df.word.isin(['@','the','to','and','a','of','is','in','"','for','i','on','you','#'])]

#Load stop words
stop_words = stopwords.words('english')
stop_words.extend(['@','"','#','&','…','-','.'])

#Show stop words
#stop_words[:100]

#Filter out the stop words
word_df = word_df[~word_df.word.isin(stop_words)]
word_df.head(50)
# Out:
#                word  count
# 11  realdonaldtrump   7936
# 17            great   5321
# 27            trump   3611
# 38            thank   2736
# 48           people   1946
# 52            would   1872
# 54              new   1785
# 55              get   1779
# 57        president   1686
# 59             like   1592
# 65             make   1454
# 69              big   1410
# 70             good   1342
# 71              one   1339
# 72            never   1321
# 76           donald   1274
# 77             many   1271
# 78          america   1257

# %%
#Sort the dataframe for plotting
word_df.sort_values(by='count',ascending=True,inplace=True)

# %%
#Graph
# %matplotlib inline
word_df.plot(x='word', y='count',kind='barh')
